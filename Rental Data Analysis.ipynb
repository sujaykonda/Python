# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.tree import DecisionTreeClassifier

# %%
data=pd.read_csv("CambridgeRentalData.csv")

# %%
data.dtypes
# Out:
# STREET_NO                object
# STREET_NAME              object
# ZIP_CODE                 object
# NO_ROOMS                  int64
# NO_BEDROOMS               int64
# NO_FULL_BATHS             int64
# NO_HALF_BATHS             int64
# SQUARE_FEET               int64
# SALE_PRICE                int64
# LIST_PRICE                int64
# ORIG_PRICE                int64
# MARKET_TIME_PROPERTY      int64
# GARAGE_SPACES_RN        float64
# ELEVATOR_RN              object
# PARKING_SPACES_RN         int64
# Avg Rent                 object
# dtype: object

# %%
x = data['SQUARE_FEET']
y = data['SALE_PRICE']
plt.scatter(x, y)

z = np.polyfit(x, y, 1)
p = np.poly1d(z)
plt.plot(x,p(x),"r--")

plt.show()

# %%
x = [\
data.NO_ROOMS.values,\
data.NO_BEDROOMS.values,\
data.NO_FULL_BATHS.values,\
data.NO_HALF_BATHS.values,\
data.SQUARE_FEET.values,\
data.SALE_PRICE.values,\
data.PARKING_SPACES_RN.values,\
]

# %%
tree_clf = DecisionTreeClassifier(max_depth=3)

# %%
tree_clf.fit(x,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-822792bde88b> in <module>
# ----> 1 tree_clf.fit(x,y)
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\sklearn\tree\tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     814             sample_weight=sample_weight,
#     815             check_input=check_input,
# --> 816             X_idx_sorted=X_idx_sorted)
#     817         return self
#     818
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\sklearn\tree\tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     248         if len(y) != n_samples:
#     249             raise ValueError("Number of labels=%d does not match "
# --> 250                              "number of samples=%d" % (len(y), n_samples))
#     251         if not 0 <= self.min_weight_fraction_leaf <= 0.5:
# ...

# %%
data
# Out:
#     STREET_NO     STREET_NAME ZIP_CODE  NO_ROOMS  NO_BEDROOMS  NO_FULL_BATHS  \
# 0          49  Orchard Street     2140         4            1              1
# 1       75-83  Cambridge Pkwy     2142         4            1              1
# 2         278      Harvard St     2139         1            1              1
# 3          69     Dana Street                  2            1              1
# 4          29    Concord Ave.     2138         3            1              1
# ..        ...             ...      ...       ...          ...            ...
# 333       395        Broadway     2139         3            1              1
# 334       603     Concord Ave     2138         2            1              1
# 335       603     Concord Ave     2138         2            1              1
# 336        87      New Street     2138         2            1              1
# 337        87      New Street     2138         2            1              1
#
# ...
